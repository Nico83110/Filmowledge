# %% [markdown]
# # FilmOWLedge project
# By CARASCO Mathias & PERRIN Nicolas

# %% [markdown]
# ## Installs + Imports

# %%
# Run only if you need to run the "Enrich data" part
# !py -m pip install -q git+https://github.com/boudinfl/pke.git
# !py -m spacy download en_core_web_sm
# !py -m pip install rdflib

# %%
from tqdm import tqdm
from time import sleep
import requests
import json
import re

# %%
import pke

# %%
from rdflib import Graph, Namespace, URIRef, Literal
from rdflib.namespace import RDF, RDFS, XSD

# %% [markdown]
# ## Gathering data from API

# %%
API_KEY = "d6103800bdd84d0eedb89128368992ff"
LANGUAGE = "en-US"
BASE_URL = "https://api.themoviedb.org/3/discover/movie?"

MAX_PAGES = 500

def set_params(url: str, **kwargs):
    param_str = ""
    for key, value in kwargs.items():
        param_str += key+'='+str(value)+'&'
    return url+param_str[:-1]

pages_json = []

for page in tqdm(range(1, MAX_PAGES)):
    url = set_params(BASE_URL,
                     api_key=API_KEY,
                     language=LANGUAGE,
                     sort_by='popularity.desc',
                     include_adult='false',
                     include_video='false',
                     with_watch_monetization_types='flatrate',
                     page=page)
    r = requests.get(url)
    json_obj = r.json()
    pages_json.append(json_obj)
    file = open(f"api_dumps/page_{str(page).zfill(5)}.json", "w")
    file.write(json.dumps(json_obj, indent=4))
    sleep(0.1)

# %%
# Concatenation of individual movies to obtain a full list of movies
movies = []
for page in pages_json:
    movies.extend(page['results'])

# %%
# Saving data into a json file
f = open("movies.json", "w")
f.write(json.dumps(movies, indent=4))
f.close()

# %%
# Loading data from file saved in a previous session
movies = []
f = open("movies.json", "r")
movies = json.loads(f.read())
f.close()

# %%
list(map(lambda x: x['original_title'], movies))
# Out:
# ['Puss in Boots: The Last Wish',
#  'Avatar: The Way of Water',
#  'Violent Night',
#  'M3GAN',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'Troll',
#  'Black Adam',
#  'Glass Onion: A Knives Out Mystery',
#  'Avatar',
#  'The Woman King',
#  'Strange World',
#  "Roald Dahl's Matilda the Musical",
#  'Savage Salvation',
#  'Prey for the Devil',
#  'High Heat',
#  'Il mio nome è vendetta',
#  'The Big 4',
#  'Black Panther: Wakanda Forever',
#  'Mal de ojo',
#  'Encanto at the Hollywood Bowl',
#  'Huevitos Congelados',
#  "Guillermo del Toro's Pinocchio",
#  'Detective Knight: Rogue',
#  'Nanatsu no Taizai: Ensa no Edinburgh - Part 1',
#  'Plan lekcji',
#  'The Independent',
#  'Avatar: The Deep Dive - A Special Edition of 20/20',
#  'Night at the Museum: Kahmunrah Rises Again',
#  'Medieval',
#  'R.I.P.D. 2: Rise of the Damned',
#  'Fall',
#  'Terrifier 2',
#  'The Boss Baby: Christmas Bonus',
#  'Hex',
#  'Снайпер. Білий ворон',
#  '미용실 : 특별한 서비스 4',
#  'The Menu',
#  'Puss in Boots',
#  'Top Gun: Maverick',
#  'Abandoned',
#  'Smile',
#  'The Minute You Wake Up Dead',
#  'Monstrous',
#  'One Way',
#  'Звёздный разум',
#  'Pinocchio',
#  "L'oubliée d'Amboise",
#  'Disenchanted',
#  'Lyle, Lyle, Crocodile',
#  'Blowback',
#  'Spider-Man: No Way Home',
#  'Leynilögga',
#  'Avatar: Creating the World of Pandora',
#  'Megan',
#  'Jurassic World Dominion',
#  'Polar',
#  'Jeepers Creepers: Reborn',
#  'Orphan: First Kill',
#  'No Abras La Puerta',
#  'Im Westen nichts Neues',
#  'Thor: Love and Thunder',
#  'Avatar: Scene Deconstruction',
#  'Paradise City',
#  'Prey',
#  'ドラゴンボール超 スーパーヒーロー',
#  'Sing 2',
#  '劇場版「鬼滅の刃」無限列車編',
#  'Beast',
#  'Sonic the Hedgehog 2',
#  'Emancipation',
#  'The Pale Blue Eye',
#  'Bullet Train',
#  'The Guardians of the Galaxy Holiday Special',
#  'Maneater',
#  'Alien Sniperess',
#  'Diary of a Wimpy Kid: Rodrick Rules',
#  'The Lair',
#  'Emily the Criminal',
#  'Blade of the 47 Ronin',
#  'Dangerous Game: The Legacy Murders',
#  'Scrooge: A Christmas Carol',
#  "Les Exploits d'un jeune Don Juan",
#  "Tom and Jerry Snowman's Land",
#  'Uncharted',
#  'Minions: The Rise of Gru',
#  'Luck',
#  '미용실 : 특별한 서비스',
#  'Doctor Strange in the Multiverse of Madness',
#  'Balle perdue 2',
#  'The Batman',
#  '20세기 소녀',
#  'Encanto',
#  'Klienten',
#  'The Lucky One',
#  'Corrective Measures',
#  'Hellraiser',
#  "Blue's Big City Adventure",
#  'On the Line',
#  'Summit Fever',
#  'Cerdita',
#  'MexZombies',
#  'Enola Holmes 2',
#  'Turning Red',
#  'La Très Très Grande Classe',
#  '鋼の錬金術師 完結編 最後の錬成',
#  'Tadeo Jones 3: La Tabla Esmeralda',
#  'Athena',
#  'Everything Everywhere All at Once',
#  'Orgasm Inc: The Story of OneTaste',
#  'In the Forest',
#  'The Soccer Football Movie',
#  '劇場版 呪術廻戦 0',
#  'The Infernal Machine',
#  'HiGH&LOW THE WORST X',
#  'A Man Called Otto',
#  'Slumberland',
#  'The Banshees of Inisherin',
#  'After Ever Happy',
#  'The Hip Hop Nutcracker',
#  '아내의 엄마 2',
#  'DC League of Super-Pets',
#  'Matar a la Bestia',
#  'Shrek',
#  '銀河英雄伝説 Die Neue These 策謀 1',
#  'The Invitation',
#  'Terrifier',
#  'Secret Headquarters',
#  'Hocus Pocus 2',
#  'Puss in Boots: The Three Diablos',
#  'El juego de las llaves',
#  'Femmine in fuga',
#  'Frank and Penelope',
#  'The Friendship Game',
#  'The Darker the Lake',
#  'Samaritan',
#  '长津湖之水门桥',
#  'The Northman',
#  'Avengers: Infinity War',
#  'Shrek 2',
#  'Kama Sutra: A Tale of Love',
#  'The Ledge',
#  'Margaux',
#  'Crawlspace',
#  '劇場版 からかい上手の高木さん',
#  'The School for Good and Evil',
#  'Where the Crawdads Sing',
#  'Harry Potter and the Half-Blood Prince',
#  '映画 五等分の花嫁',
#  '僕のヒーローアカデミア THE MOVIE ワールド ヒーローズ ミッション',
#  'The Super Mario Bros. Movie',
#  'Overdose',
#  'Sechs Schwedinnen im Pensionat',
#  'Hotel Transylvania: Transformania',
#  'The Black Phone',
#  'Puss in Book: Trapped in an Epic Tale',
#  'X',
#  'Whisper',
#  'The Lost City',
#  'Fantastic Beasts: The Secrets of Dumbledore',
#  'The Action Pack Saves Christmas',
#  'In from the Side',
#  'White Noise',
#  'Bromates',
#  'Noc w przedszkolu',
#  'Hacksaw Ridge',
#  'రౌద్రం రణం రుధిరం',
#  'Harry Potter and the Goblet of Fire',
#  'Lolita',
#  'Nightride',
#  'Watcher',
#  'Bones and All',
#  'Megan',
#  'The Fabelmans',
#  'Titanic',
#  'The Exorcism of God',
#  "Harry Potter and the Philosopher's Stone",
#  '7 donne e un mistero',
#  'Venom: Let There Be Carnage',
#  'Harry Potter and the Chamber of Secrets',
#  'Shang-Chi and the Legend of the Ten Rings',
#  '雨を告げる漂流団地',
#  '強姦終極篇之最後羔羊',
#  '金瓶梅2 愛的奴隸',
#  'Wild Is the Wind',
#  'Lou',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Memory',
#  'Kolejne 365 dni',
#  'Me contro Te: Il film - Persi nel tempo',
#  'Code Name Banshee',
#  'Iron Man 2',
#  'Harry Potter and the Deathly Hallows: Part 2',
#  '映画『ゆるキャン△』',
#  '鋼の錬金術師 完結編 復讐者スカー',
#  'Black Panther',
#  '映画ドラえもん のび太の宇宙小戦争 2021',
#  '늑대사냥',
#  'Harry Potter and the Order of the Phoenix',
#  'Grimcutty',
#  'The Red Book Ritual',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Ant-Man and the Wasp: Quantumania',
#  'The Jack in the Box: Awakening',
#  'Avatar 4',
#  'Terrifier',
#  'El monte',
#  'Lightyear',
#  'Men',
#  'Dracula: The Original Living Vampire',
#  'Morbius',
#  'The Equalizer',
#  '明日戰記',
#  'Moonfall',
#  'Life in a Year',
#  '劇場版 七つの大罪 光に呪われし者たち',
#  'The Bad Guys',
#  'The Takeover',
#  'Operation Fortune: Ruse de Guerre',
#  'The Long Dark Trail',
#  'Más respeto que soy tu madre',
#  'The Maze Runner',
#  'The Twin',
#  'Blackout',
#  'Nefeli',
#  "Reno 911!: It's a Wonderful Heist",
#  'A Prince in Paradise',
#  'The Fallout',
#  'The Visitor',
#  'The Ice Age Adventures of Buck Wild',
#  '서울대작전',
#  'The Boss Baby: Family Business',
#  'Welcome to the Club',
#  'Togo',
#  'Özel Ders',
#  'Madagascar: A Little Wild Holiday Goose Chase',
#  'The Princess',
#  'Girl at the Window',
#  'Babylon',
#  'The Enforcer',
#  '젊은 친구엄마',
#  'Arsenault & Fils',
#  'The Whale',
#  'Cruella',
#  'Transformers: Rise of the Beasts',
#  "Lady Chatterley's Lover",
#  'Well Suited For Christmas',
#  'Nope',
#  'Sulle nuvole',
#  '365 Days: This Day',
#  'Shrek Forever After',
#  'Interstellar',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Eternals',
#  'Padre no hay mas que Uno 3',
#  '이채담의 지스팟',
#  'Mortal Kombat',
#  "My Father's Dragon",
#  "You Won't Be Alone",
#  '鬼滅の刃 兄妹の絆',
#  'Ice Age',
#  'Halloween Ends',
#  '20/20 Presents Black Panther: In Search of Wakanda',
#  '私の奴隷になりなさい',
#  'Batman and Superman: Battle of the Super Sons',
#  'Topside',
#  'Cosas de amigos',
#  'Scream',
#  "Let's Be Cops",
#  'Godzilla vs. Kong',
#  'Shrek the Third',
#  "Zack Snyder's Justice League",
#  'Finding Nemo',
#  '여친 엄마2',
#  'ONE PIECE FILM RED',
#  'Dog',
#  'Dragon Knight',
#  'The Avengers',
#  'Tropa de Elite',
#  'Avengers: Endgame',
#  'Coco',
#  '스와핑 : 완벽한 이웃',
#  'Matando el tiempo',
#  'The Man from Rome',
#  'Summer Ghost',
#  'Sniper: Rogue Mission',
#  'Sicosexual',
#  "Don't Worry Darling",
#  'F9',
#  'Satánico pandemonium: la sexorcista',
#  'The Addams Family 2',
#  'とつくにの少女',
#  'The Green Mile',
#  'Inside Out',
#  'The Suicide Squad',
#  'Q',
#  '13 หมูป่า: เรื่องเล่าจากในถ้ำ',
#  'Wire Room',
#  'Evil Dead Rise',
#  'The Conjuring: The Devil Made Me Do It',
#  'Los reyes del mundo',
#  'Day Shift',
#  'The Twilight Saga: Eclipse',
#  'Monster High: The Movie',
#  'EUREKA／交響詩篇エウレカセブン\u3000ハイエボリューション',
#  'After We Fell',
#  '헤어질 결심',
#  'Star Wars',
#  'Black Widow',
#  'Top Gun',
#  'Brothers',
#  'Barbarian',
#  'The Sea Beast',
#  'The Matrix Resurrections',
#  'Last Seen Alive',
#  'Forrest Gump',
#  'The Tomorrow War',
#  'BORUTO -NARUTO THE MOVIE-',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Toy Story',
#  'Jaula',
#  'Reviviendo la Navidad',
#  'Mia and Me: The Hero of Centopia',
#  'The Stranger',
#  'After',
#  'Monsters, Inc.',
#  'Sonic the Hedgehog',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'The Croods: A New Age',
#  'Los renglones torcidos de Dios',
#  'Wrath of Man',
#  'グッバイ、ドン・グリーズ！',
#  '劇場版 NARUTO -ナルト- 疾風伝',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'Luca',
#  'Transformers: Age of Extinction',
#  'La Princesa',
#  'Trick or Treat Scooby-Doo!',
#  "Qu'est-ce qu'on a tous fait au Bon Dieu ?",
#  'Avengers: Age of Ultron',
#  'Family History Mysteries: Buried Past',
#  'صالون هدى',
#  'After We Collided',
#  'The Dark Knight',
#  'Avatar 5',
#  'So Cold the River',
#  'Resident Evil: Welcome to Raccoon City',
#  'The Hunger Games: Mockingjay - Part 1',
#  'Devotion',
#  'Twilight',
#  'Raya and the Last Dragon',
#  '君の名は。',
#  'Mortal Kombat Legends: Snow Blind',
#  'Paws of Fury: The Legend of Hank',
#  'Blacklight',
#  'The Godfather Part III',
#  '11th Hour Cleaning',
#  'The Requin',
#  'Alle hater Johan',
#  'L.O.L. Surprise! Winter Fashion Show',
#  'Mete miedo',
#  'Bullet Proof',
#  'Deinfluencer',
#  'The Godfather',
#  'Red Notice',
#  'The Gray Man',
#  'ドラゴンボールZ 復活の「F」',
#  'The Simpsons Movie',
#  'Deadpool',
#  'The Hangover',
#  'The Hobbit: The Battle of the Five Armies',
#  'Avatar 3',
#  'Looks Can Kill',
#  'Elvis',
#  'The Help',
#  'Miraculous World: Shanghai, la légende de Ladydragon',
#  'Knives Out',
#  '동창회의 목적 3',
#  '劇場版 ソードアート・オンライン-プログレッシブ- 星なき夜のアリア',
#  'Tangled',
#  '一周的朋友',
#  'Dune',
#  'Office Invasion',
#  'The Lion King',
#  'John Wick: Chapter 3 - Parabellum',
#  'Bridge to Terabithia',
#  '映画 オッドタクシー イン・ザ・ウッズ',
#  'The Last: Naruto the Movie',
#  'Call Jane',
#  'PAW Patrol: The Movie',
#  "Groot's First Steps",
#  'Mack & Rita',
#  'The Wolf of Wall Street',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Conjuring',
#  '淫乱なる一族 第二章 絶倫の果てに',
#  'Coraline',
#  'Terminator Genisys',
#  '僕のヒーローアカデミア THE MOVIE ヒーローズ：ライジング',
#  'Miraculous World : New York, les héros unis',
#  'Matriarch',
#  'Spider-Man: Homecoming',
#  'Nebo',
#  'Inexorable',
#  'John Wick: Chapter 2',
#  "The King's Man",
#  'Hidden Figures',
#  'Ted 2',
#  '더 킬러: 죽어도 되는 아이',
#  'Fast X',
#  'Wakanda',
#  'Your Boyfriend Is Mine',
#  'Capturing Avatar',
#  'The Man from Toronto',
#  'Clifford the Big Red Dog',
#  '...Altrimenti ci arrabbiamo!',
#  'Under Wraps 2',
#  'Solo amor y mil canciones',
#  'Big Hero 6',
#  'How to Train Your Dragon: The Hidden World',
#  'John Wick: Chapter 4',
#  'Titane',
#  '룸싸롱 여대생들 3',
#  'Plane',
#  'Fury',
#  'The Call of the Wild',
#  '미용실 특별한 서비스 2',
#  'The Twilight Saga: Breaking Dawn - Part 1',
#  'Spider-Man: Into the Spider-Verse',
#  '비상선언',
#  'Shark Bait',
#  'Zootopia',
#  'She Said',
#  'Frozen II',
#  'How to Train Your Dragon 2',
#  '七つの大罪: 怨嗟のエジンバラ',
#  'The Simpsons in Plusaversary',
#  'Purple Hearts',
#  'The Amazing Spider-Man 2',
#  'Up',
#  'Barbie Epic Road Trip',
#  'Orphan',
#  'Ready Player One',
#  'Slayers',
#  'Ghostbusters: Afterlife',
#  'Barbie: Mermaid Power',
#  'Taken 3',
#  'Ash & Dust',
#  'The Shawshank Redemption',
#  'The Forever Purge',
#  'Padre no hay más que uno',
#  '카터',
#  'Undisputed III: Redemption',
#  'Me Before You',
#  '옆방에 일본여자가 싼다',
#  'Fast & Furious Presents: Hobbs & Shaw',
#  'ปฏิบัติการกู้หวย',
#  'The Lion King',
#  'Home Alone 2: Lost in New York',
#  'World War Z',
#  'Groot Takes a Bath',
#  'Depois do Universo',
#  '団鬼六\u3000女秘書縄調教',
#  'Spider-Man',
#  'The Amazing Spider-Man',
#  'Kimi',
#  'The Conjuring 2',
#  'Wendell & Wild',
#  'Kung Fu Panda',
#  '黄金大逃狱',
#  'Ratatouille',
#  'Cinderella',
#  'White Elephant',
#  'Wrong Turn 3: Left for Dead',
#  'Megan Is Missing',
#  'xXx: Return of Xander Cage',
#  'Project X',
#  'The Next Three Days',
#  'Free Guy',
#  'The Lord of the Rings: The Return of the King',
#  'Toy Story 2',
#  'Hunting Ava Bravo',
#  'The Fifth Element',
#  'Tres metros sobre el cielo',
#  'Tropa de Elite 2',
#  'The Adam Project',
#  'Transformers: The Last Knight',
#  'The Princess and the Frog',
#  'No Exit',
#  'Black Site',
#  'Fifty Shades of Grey',
#  'No Time to Die',
#  'Homebound',
#  '僕のヒーローアカデミア THE MOVIE ～2人の英雄～',
#  'Inception',
#  'Frozen',
#  'Joker',
#  'Mulan',
#  'Charlie and the Chocolate Factory',
#  'Last Man Down',
#  'Sing',
#  'Iron Man',
#  'Jungle Cruise',
#  'The Hangover Part II',
#  'V/H/S/99',
#  'Eternal Sunshine of the Spotless Mind',
#  'Fifty Shades Freed',
#  'Addams Family Values',
#  'TÁR',
#  'Black Adam: Saviour or Destroyer?',
#  'Cars 3',
#  '착한 형수2',
#  'Meet Joe Black',
#  'A través de mi ventana',
#  'The Nun',
#  '외계+인 1부',
#  'ドラゴンボールＺ 燃え尽きろ!!熱戦・烈戦・超激戦',
#  'Последний богатырь: Корень зла',
#  "Pirates of the Caribbean: At World's End",
#  'Captain America: Civil War',
#  'Wonder Woman 1984',
#  'Virus :32',
#  'Kangaroo Valley',
#  'Texas Chainsaw Massacre',
#  'The Addams Family',
#  'Thor: Ragnarok',
#  'Kill Bill: Vol. 1',
#  'The Contractor',
#  "Don't Breathe 2",
#  'Lagunas, la guarida del diablo',
#  'How the Grinch Stole Christmas',
#  'La chiave',
#  'Harry Potter 20th Anniversary: Return to Hogwarts',
#  'Boyka: Undisputed IV',
#  'Triangle of Sadness',
#  'Grown Ups 2',
#  'Catch the Fair One',
#  '마녀 2',
#  'Spider-Man: Far from Home',
#  'Scary Movie',
#  'A Trip to Infinity',
#  'Mad Max: Fury Road',
#  'Cinderella',
#  'The Grinch',
#  "Devil's Workshop",
#  '하숙집 : 굶주린 늑대들',
#  'Three Thousand Years of Longing',
#  'Cuando Sea Joven',
#  'Real Steel',
#  'Aftersun',
#  'Mulan',
#  'Spirited',
#  'Kung Fu Panda 3',
#  '범죄도시 2',
#  'The Hangover Part III',
#  '劇場版 NARUTO -ナルト- ブラッド・プリズン',
#  'The Unbearable Weight of Massive Talent',
#  'Creed II',
#  'The SpongeBob Movie: Sponge on the Run',
#  'Ant-Man',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#  'Indiana Jones and the Last Crusade',
#  'John Q',
#  'Cars 2',
#  '2012',
#  'The Addams Family',
#  'It Chapter Two',
#  'Terrifier 3',
#  'Jurassic World',
#  'Spider-Man 3',
#  'Monster Hunter',
#  'Grown Ups',
#  'Iron Man 3',
#  'Libélulas',
#  'ARIA The BENEDIZIONE',
#  'Blade Runner',
#  'Tomorrowland',
#  'Ambulance',
#  'Deadpool 2',
#  'Jupiter Ascending',
#  '玉蒲團',
#  'The Little Mermaid',
#  'Sechs Schwedinnen auf der Alm',
#  'The Lord of the Rings: The Two Towers',
#  'A Quiet Place Part II',
#  '咒',
#  'Fight Club',
#  'Doctor Strange',
#  'Deathstroke: Knights & Dragons - The Movie',
#  'Pamasahe',
#  'Apocalypse Now',
#  'Jumanji: The Next Level',
#  '千と千尋の神隠し',
#  'End of the Road',
#  'Spider-Man: Across the Spider-Verse',
#  'Чернобыль',
#  'How to Train Your Dragon',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Teenage Mutant Ninja Turtles',
#  'American Sniper',
#  'Presencias',
#  'ドラゴンボールZ 龍拳爆発!!悟空がやらねば誰がやる',
#  'Selena Gomez: My Mind & Me',
#  '신과함께-죄와 벌',
#  'The Outfit',
#  'Twelve Monkeys',
#  "Roald Dahl's The Witches",
#  'The Fate of the Furious',
#  'El hoyo en la cerca',
#  'Shrek 5',
#  '딸의 친구 5',
#  'The Hobbit: An Unexpected Journey',
#  '映画 聲の形',
#  'Indiana Jones and the Temple of Doom',
#  'Panibugho',
#  'Soul',
#  'Space Jam: A New Legacy',
#  'Just Go with It',
#  'Creed',
#  'Padre no hay más que uno 2: la llegada de la suegra',
#  'Spiderhead',
#  'Despicable Me 2',
#  'Penguins of Madagascar',
#  'Magnum Opus',
#  'San Andreas',
#  '맛있는 비행',
#  'Kung Fu Panda 2',
#  '미용실 : 특별한 서비스 3',
#  'Toy Story 4',
#  'The Twilight Saga: New Moon',
#  'The Meg',
#  'Ted',
#  'ワンパンマン ロード・トゥー・ヒーロー',
#  'Blade Runner 2049',
#  'Corpse Bride',
#  'A Walk Among the Tombstones',
#  'Werewolf by Night',
#  'Infinite',
#  'John Wick',
#  '泣きたい私は猫をかぶる',
#  'ハウルの動く城',
#  '이모의 유혹 3',
#  'Ice Age: The Meltdown',
#  'American Beauty',
#  'Jurassic World: Fallen Kingdom',
#  'Finch',
#  'Nobody',
#  'Furious 7',
#  'Taken',
#  '한산: 용의 출현',
#  '暴虐女拷問',
#  'Raiders of the Lost Ark',
#  'Evil Dead',
#  'Batman v Superman: Dawn of Justice',
#  'Ava',
#  'The Penitent Thief',
#  'Abraham Lincoln: Vampire Hunter',
#  'Ava',
#  'The Parent Trap',
#  'Amsterdam',
#  'Un crimen argentino',
#  '새오빠2',
#  'Justice League',
#  'るろうに剣心 最終章 The Beginning',
#  '(500) Days of Summer',
#  'Winnie the Pooh: Blood and Honey',
#  'The Unholy',
#  'Maleficent: Mistress of Evil',
#  'Toy Story 3',
#  'Du som er i himlen',
#  '딸의 친구 4',
#  'Honor Society',
#  'The Mummy',
#  '劇場版 転生したらスライムだった件 紅蓮の絆編',
#  'Tarzan',
#  'Wrong Turn',
#  '風の谷のナウシカ',
#  'Thor',
#  'Código Emperador',
#  'Terminator 2: Judgment Day',
#  'Madagascar',
#  'Wrong Turn 2: Dead End',
#  '이공삼칠',
#  'The Dark Knight Rises',
#  'Citizen Kane',
#  '女医肉奴隷',
#  'Maze Runner: The Scorch Trials',
#  'The Wonder',
#  'まるだせ金太狼',
#  'Pacific Rim',
#  "Chip 'n Dale: Rescue Rangers",
#  'Las Leyendas: El Origen',
#  'American Sicario',
#  'Road to Ninja: Naruto the Movie',
#  '탐하다: 욕망의 섬',
#  'Taken 2',
#  'Zoolander',
#  '3D肉蒲團之極樂寶鑑',
#  'I Believe in Santa',
#  'Split',
#  'Pulp Fiction',
#  'Constantine: The House of Mystery',
#  '구멍동서 2',
#  'Incredibles 2',
#  'Aladdin',
#  'Willow',
#  '2001: A Space Odyssey',
#  'バブル',
#  'All My Friends Hate Me',
#  'The Cellar',
#  'Prometheus',
#  'Beauty and the Beast',
#  'Virgin Forest',
#  'Jarhead',
#  'Gladiator',
#  'WarHunt',
#  "The Lion King II: Simba's Pride",
#  'The Boy in the Striped Pyjamas',
#  'Venom',
#  'The Matrix',
#  'Cat Pack: A PAW Patrol Exclusive Event',
#  'Ripper Untold',
#  'The Greatest Beer Run Ever',
#  "From Straight A's to XXX",
#  'The Fly',
#  '부산행',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'Maze Runner: The Death Cure',
#  '신과함께-인과 연',
#  'Army of the Dead',
#  'Five Feet Apart',
#  'The House',
#  'The Last Duel',
#  'Knowing',
#  'The Exorcist',
#  'La abuela',
#  'Stowaway',
#  'Superbad',
#  'The Desperate Hour',
#  'Snake Eyes: G.I. Joe Origins',
#  'Need for Speed',
#  'Collision',
#  'Бука. Моё любимое чудище',
#  'The Incredibles',
#  'Armageddon',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'Pokémon Detective Pikachu',
#  'Wish Dragon',
#  'ドラゴンボールGT 悟空外伝! 勇気の証しは四星球(スーシンチュウ)',
#  'Godzilla: King of the Monsters',
#  '화끈한 미용실',
#  'Whiplash',
#  'Color My World with Love',
#  'ミュウツーの逆襲 EVOLUTION',
#  '美姉妹・剥ぐ',
#  'Hustle',
#  '기생충',
#  'The Shack',
#  'Clean',
#  'Top Sensation',
#  'Panama',
#  'Man of Steel',
#  '야차',
#  'Annabelle Comes Home',
#  'Ice Age: Continental Drift',
#  'The Karate Kid',
#  'The Little Guy',
#  'Matilda',
#  'Gold',
#  'Us X Her',
#  'King',
#  'Crank: High Voltage',
#  'The Notebook',
#  'Sonic the Hedgehog 3',
#  'Scary Movie 5',
#  'THE FIRST SLAM DUNK',
#  'Unforgiven',
#  'Snow White and the Seven Dwarfs',
#  'Brave',
#  'Ruido',
#  'Chronicle',
#  'Scary Movie 2',
#  'Wreck-It Ralph',
#  "Tom Clancy's Without Remorse",
#  'Spirit Halloween: The Movie',
#  'Halloween Kills',
#  'Maleficent',
#  'Edge of Tomorrow',
#  '친구부부 : 욕망의 스와핑',
#  'Journey 2: The Mysterious Island',
#  'The Evil Dead',
#  'Exodus: Gods and Kings',
#  "Selina's Gold",
#  'Fantastic Beasts and Where to Find Them',
#  'Pornô!',
#  'Guardians of the Galaxy Vol. 2',
#  'Girl in the Basement',
#  'Ostatnia Wieczerza',
#  'Nightcrawler',
#  '玉蒲團之偷情寶鑑',
#  'Black Water: Abyss',
#  'Terminator: Dark Fate',
#  'Spirit Untamed',
#  '룸싸롱 : 맛있는 서비스2',
#  'Adanis: Kutsal Kavga',
#  'Logan',
#  'Constantine',
#  'Trolls',
#  'Star Wars: The Force Awakens',
#  'Pinocchio',
#  'American Psycho',
#  'Spirit: Stallion of the Cimarron',
#  'The Hunger Games: Catching Fire',
#  'Memento',
#  'Dirty Dancing',
#  'Vendetta',
#  'Nightmare Alley',
#  '17 Again',
#  'Sous emprise',
#  'Baise-moi',
#  'Tom and Jerry Cowboy Up!',
#  'Christmas Unfiltered',
#  'Knock at the Cabin',
#  'Спутник',
#  'Love & Other Drugs',
#  'Le Patient',
#  'The Marksman',
#  'Rio',
#  'The Nightmare Before Christmas',
#  'El laberinto del fauno',
#  'The Hunger Games: Mockingjay - Part 2',
#  'Lilo & Stitch',
#  'Wrong Turn',
#  'Thor: The Dark World',
#  'The Last Airbender',
#  'The Hatchet Wielding Hitchhiker',
#  'Secret of the Wings',
#  'Intouchables',
#  '착한 엄마 3',
#  'WALL·E',
#  'Scooby-Doo',
#  'ドラゴンボールＺ 危険なふたり！超戦士はねむれない',
#  'American History X',
#  'The Equalizer 2',
#  'Scarface',
#  'Her',
#  'Gone Girl',
#  '劇場版 ポケットモンスター\u3000キミにきめた！',
#  'Shazam!',
#  'The Good Nurse',
#  '9 Songs',
#  'El Infierno',
#  'Pinocchio',
#  'Southpaw',
#  'Monsters University',
#  '真・三國無双',
#  'White Chicks',
#  'Malnazidos',
#  "A Bug's Life",
#  'Ninja Assassin',
#  'Fifty Shades Darker',
#  'Bound by Honor',
#  'Metropolis',
#  'ドラゴンボールZ 神と神',
#  "Mr. Harrigan's Phone",
#  'Pearl',
#  "The Emperor's New Groove",
#  'Tom & Jerry',
#  '魔女の宅急便',
#  'Bring It On: Cheer Or Die',
#  'Sex Tape',
#  'Blonde',
#  'Bad Boys for Life',
#  'Limitless',
#  'Titanic 666',
#  'Un rescate de huevitos',
#  '비뇨기과 여의사들 2',
#  '劇場版 NARUTO -ナルト- 疾風伝 ザ・ロストタワー',
#  'Jeepers Creepers',
#  'Cars',
#  '어린 이모 2',
#  'ドラゴンボールZ たったひとりの最終決戦〜フリーザに挑んだZ戦士 孫悟空の父〜',
#  'Old',
#  "Miss Peregrine's Home for Peculiar Children",
#  'Grounded: Making The Last of Us',
#  "It's a Wonderful Binge",
#  'Fate/Grand Order -終局特異点 冠位時間神殿ソロモン-',
#  'The Croods',
#  'American Pie',
#  'The Aviary',
#  'Alien',
#  'Fistful of Vengeance',
#  'Kong: Skull Island',
#  'A Haunted House 2',
#  'The Swimmers',
#  'Final Destination',
#  'Hercules',
#  'Rise of the Guardians',
#  '崖の上のポニョ',
#  'Predator',
#  'No Manches Frida 2',
#  'ONE PIECE “3D2Y” エースの死を越えて! ルフィ仲間との誓い',
#  'Back to the Future',
#  '劇場版 NARUTO -ナルト- 疾風伝 絆',
#  'Shut In',
#  'X-Men: Apocalypse',
#  'Interceptor',
#  'Inspector Sun y la maldición de la viuda negra',
#  'House Party',
#  'After Porn Ends 3',
#  "Madagascar 3: Europe's Most Wanted",
#  'Beneath the Surface',
#  '竜とそばかすの姫',
#  'The Hobbit: The Desolation of Smaug',
#  'Predators',
#  'The Town',
#  'Aladdin',
#  'Wrong Turn 5: Bloodlines',
#  'Batman Begins',
#  'The Proposal',
#  'Vesper',
#  'The Mummy Returns',
#  'Hotel Transylvania',
#  'Teen Titans Go! & DC Super Hero Girls: Mayhem in the Multiverse',
#  'Superfast!',
#  'John Carter',
#  'The Blind Side',
#  'La donna per me',
#  'Pixels',
#  'Miraculous: Le Film',
#  'Annabelle: Creation',
#  'El Guau',
#  'The Terminator',
#  'Birds of Prey (and the Fantabulous Emancipation of One Harley Quinn)',
#  'Alita: Battle Angel',
#  'Run Sweetheart Run',
#  '機動戦士ガンダム 閃光のハサウェイ',
#  'The Godfather Part II',
#  'Babardeala cu bucluc sau porno balamuc',
#  'Despicable Me',
#  'Hercules',
#  'Amores perros',
#  'Ralph Breaks the Internet',
#  'Mission: Impossible - Fallout',
#  'Jeepers Creepers 2',
#  '重启地球',
#  'La véritable histoire du Chat Botté',
#  '브로커',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Good Dinosaur',
#  'Lucy',
#  'Heat',
#  'Antlers',
#  'Larva Pendant',
#  'Heatwave',
#  'Fireheart',
#  '劇場版ポケットモンスター ココ',
#  'Scream',
#  '아가씨',
#  'Sechs Schwedinnen von der Tankstelle',
#  'The Passion of the Christ',
#  '劇場版 NARUTO -ナルト- 疾風伝 火の意志を継ぐ者',
#  'Sohn meines Vaters',
#  'Hancock',
#  '劇場版 ヴァイオレット・エヴァーガーデン',
#  'The Nun II',
#  'One Shot',
#  'Ice Age: Collision Course',
#  'Dancer in the Dark',
#  'Insurgent',
#  'Clash of the Titans',
#  "Ron's Gone Wrong",
#  'A Haunted House',
#  'Ｍ家の新妻\u3000変態洗礼',
#  'Madagascar: Escape 2 Africa',
#  'The Devil Wears Prada',
#  'Ford v Ferrari',
#  'Veneciafrenia',
#  'La caída',
#  'Get Out',
#  'Me Time',
#  'Catch Me If You Can',
#  'Anastasia',
#  'Pain & Gain',
#  'Legion',
#  '장모학개론',
#  '신혼부부의 성생활',
#  'Wonder Woman',
#  'Baby Driver',
#  'The Thing',
#  'Creed III',
#  '8 Mile',
#  '天気の子',
#  "Obi-Wan Kenobi: A Jedi's Return",
#  'American Pie Presents: The Book of Love',
#  'Four Rooms',
#  'The Commando',
#  'The Expendables',
#  'The Wizard of Oz',
#  'Dawn of the Planet of the Apes',
#  'Loin du périph',
#  ...]

# %%
movies[0]
# Out:
# {'adult': False,
#  'backdrop_path': '/r9PkFnRUIthgBp2JZZzD380MWZy.jpg',
#  'genre_ids': [16, 28, 12, 35, 10751, 14],
#  'id': 315162,
#  'original_language': 'en',
#  'original_title': 'Puss in Boots: The Last Wish',
#  'overview': 'Puss in Boots discovers that his passion for adventure has taken its toll: He has burned through eight of his nine lives, leaving him with only one life left. Puss sets out on an epic journey to find the mythical Last Wish and restore his nine lives.',
#  'popularity': 10563.563,
#  'poster_path': '/1NqwE6LP9IEdOZ57NCT51ftHtWT.jpg',
#  'release_date': '2022-12-21',
#  'title': 'Puss in Boots: The Last Wish',
#  'video': False,
#  'vote_average': 8.6,
#  'vote_count': 1067}

# %% [markdown]
# ## Enrich data
# The goal is now to enrich data by linking topics to movies. This will be achieved by using a Topic Modeling method to extract topics from the title of the movie and its overview (summary).

# %%
# initialize keyphrase extraction model, here TopicRank
extractor = pke.unsupervised.TopicRank()

def extract_keyphrases(extractor, text, n=20):
    # load the content of the document, here document is expected to be a simple 
    # test string and preprocessing is carried out using spacy
    extractor.load_document(input=text, language='en')

    # keyphrase candidate selection, in the case of TopicRank: sequences of nouns
    # and adjectives (i.e. `(Noun|Adj)*`)
    extractor.candidate_selection()

    # candidate weighting, in the case of TopicRank: using a random walk algorithm
    extractor.candidate_weighting()

    # N-best selection, keyphrases contains the 10 highest scored candidates as
    # (keyphrase, score) tuples
    keyphrases = extractor.get_n_best(n=n)

    return keyphrases

extract_keyphrases(extractor, movies[1]['original_title']+'. '+movies[1]['overview'])
# Out:
# [('jake', 0.09464521347108282),
#  ('sully family', 0.08989761729212997),
#  ('neytiri', 0.08618092059003643),
#  ('way', 0.0744264160136417),
#  ('water', 0.07197708073300846),
#  ('kids', 0.07044810574474102),
#  ('story', 0.06869781004088565),
#  ('decade', 0.06467604488367745),
#  ('events', 0.06388551888300528),
#  ('trouble', 0.062358157270368884),
#  ('avatar', 0.05586951509177656),
#  ('alive', 0.05207573286481042),
#  ('lengths', 0.051339732762403424),
#  ('battles', 0.04885121937074795),
#  ('tragedies', 0.04467091498768399)]

# %%
def cleanup_topic(topic):
    return re.sub(r'[^a-zA-Z0-9 ]', '', topic.replace('-', ' '))

cleanup_topic("epic-journey²*!")
# Out:
# 'epic journey'

# %%
# We do the operation on each movie, so we have associated topics for each of them.
'''
for movie in tqdm(movies):
    movie["topics"] = list(map(lambda x: x[0],
                               extract_keyphrases(extractor, movie['original_title']+'. '+movie['overview'])
                              )
                          )
'''
for movie in tqdm(movies):
    list_of_topics = []
    for topic, _ in extract_keyphrases(extractor, movie['original_title']+'. '+movie['overview']):
        cleaned_topic = cleanup_topic(topic)
        if cleaned_topic.replace(' ', ''):
            list_of_topics.append(cleaned_topic)
    movie["topics"] = list_of_topics
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [1:35:00<00:00,  1.75it/s]

# %%
@todo: remmove because already integrated to previous cell
# Postprocessing: we clean the topics (remove non alphanumeric caracters)
for movie in tqdm(movies):
    list_of_topics = []
    for topic in movie["topics"]:
        cleaned_topic = cleanup_topic(topic)
        if cleaned_topic.replace(' ', ''):
            list_of_topics.append(cleaned_topic)
    movie["topics"] = list_of_topics
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 85721.55it/s]

# %%
# Saving the enriched data in the json format.
f = open("movies_enriched.json", "w")
f.write(json.dumps(movies, indent=4))
f.close()

# %%
# Loading enriched data from previous session
movies = []
f = open("movies_enriched.json", "r")
movies = json.loads(f.read())
f.close()

# %%
movies[1]
# Out:
# {'adult': False,
#  'backdrop_path': '/s16H6tpK2utvwDtzZ8Qy4qm5Emw.jpg',
#  'genre_ids': [878, 12, 28],
#  'id': 76600,
#  'original_language': 'en',
#  'original_title': 'Avatar: The Way of Water',
#  'overview': 'Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.',
#  'popularity': 3495.153,
#  'poster_path': '/t6HIqrRAclMCA60NsSmeqe9RmNV.jpg',
#  'release_date': '2022-12-16',
#  'title': 'Avatar: The Way of Water',
#  'video': False,
#  'vote_average': 7.7,
#  'vote_count': 3990,
#  'topics': ['jake',
#   'sully family',
#   'neytiri',
#   'way',
#   'water',
#   'kids',
#   'story',
#   'decade',
#   'events',
#   'trouble',
#   'avatar',
#   'alive',
#   'lengths',
#   'battles',
#   'tragedies']}

# %%
# We show an overview of the different topics that have been collected and the number of movies each topic is associated with.

topics = {}
for movie in tqdm(movies):
    for topic in movie["topics"]:
        if topic in topics:
            topics[topic] += 1
        else:
            topics[topic] = 1

all_topics = list(topics.keys())
topics
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 10000/10000 [00:00<00:00, 141817.32it/s]
# {'puss': 7,
#  'boots': 9,
#  'passion': 23,
#  'adventure': 73,
#  'lives': 242,
#  'toll': 6,
#  'life': 830,
#  'epic journey': 12,
#  'jake': 9,
#  'sully family': 1,
#  'neytiri': 1,
#  'way': 391,
#  'water': 26,
#  'kids': 82,
#  'story': 314,
#  'decade': 14,
#  'events': 125,
#  'trouble': 66,
#  'avatar': 13,
#  'alive': 61,
#  'lengths': 4,
#  'battles': 6,
#  'tragedies': 4,
#  'team': 162,
#  'wealthy family compound': 1,
#  'christmas eve': 22,
#  'santa claus': 15,
#  'mercenaries': 13,
#  'surprise combatant': 1,
#  'hostage': 20,
#  'grounds': 3,
#  'nick': 22,
#  'violent night': 1,
#  'saint': 4,
#  'life like doll': 2,
#  'm3gan': 1,
#  'artificial intelligence': 3,
#  'new friend': 10,
#  'brilliant toy company roboticist': 1,
#  'programming works': 1,
#  'overprotective': 1,
#  'terrifying results': 1,
#  'niece': 21,
#  'narnia': 3,
#  'witch': 14,
#  'lion': 11,
#  'wardrobe': 4,
#  'siblings lucy': 1,
#  'edmund': 3,
#  'susan': 7,
#  'children': 141,
#  'aslan': 1,
#  'climactic battle': 2,
#  'spectacular': 5,
#  'peter': 25,
#  'wise': 7,
#  'jadis': 1,
#  'land': 88,
#  'free': 36,
#  'eternal winter': 2,
#  'peaceful kingdom': 1,
#  'charming': 9,
#  'glacial powers': 1,
#  'dovre': 1,
#  'mountain': 13,
#  'capital': 9,
#  'creature': 22,
#  'norway': 8,
#  'gigantic awakens': 1,
#  'path': 51,
#  'years': 500,
#  'troll': 3,
#  'norwegian folklore': 1,
#  'unique form': 1,
#  'justice': 62,
#  'ready': 57,
#  'earthly tomb': 1,
#  'modern world': 9,
#  'black adam': 3,
#  'almighty powers': 1,
#  'mystery': 76,
#  'world famous detective benoit blanc': 1,
#  'knives': 2,
#  'eclectic crew': 1,
#  'tech billionaire': 3,
#  'layers': 3,
#  'greece': 8,
#  'friends': 348,
#  'glass onion': 1,
#  'paraplegic marine': 1,
#  'moon pandora': 1,
#  '22nd century': 5,
#  'unique mission': 1,
#  'orders': 14,
#  'alien civilization': 1,
#  '1800s': 2,
#  'dahomey': 1,
#  'skills': 20,
#  'african kingdom': 1,
#  'all female unit': 1,
#  'warriors': 15,
#  'fierceness': 1,
#  'agojie': 1,
#  'world': 660,
#  'enemy': 32,
#  'battle': 111,
#  'woman king': 1,
#  'general nanisca': 1,
#  'recruits': 6,
#  'treacherous land': 1,
#  'uncharted': 4,
#  'differences': 24,
#  'explorers': 8,
#  'fantastical creatures': 1,
#  'journey': 147,
#  'crucial': 3,
#  'mission': 156,
#  'latest': 6,
#  'strange world': 3,
#  'summons': 2,
#  'superpower': 1,
#  'matilda': 3,
#  'remarkable courage': 2,
#  'extraordinary young girl': 1,
#  'musical': 7,
#  'roald dahl': 2,
#  'odds': 20,
#  'stories': 39,
#  'charge': 28,
#  'right': 36,
#  'miraculous results': 1,
#  'shelby john': 1,
#  'struggles': 12,
#  'vigilante justice': 2,
#  'addiction': 5,
#  'end': 135,
#  'nail gun': 1,
#  'fresh start': 4,
#  'ruby red': 1,
#  'beloved ruby dead': 1,
#  'sheriff church': 1,
#  'crime lord coyote': 1,
#  'vengeful killing spree': 1,
#  'porch': 2,
#  'clock': 22,
#  'entire town': 6,
#  'adrenaline': 2,
#  'dealers': 3,
#  'chaos': 51,
#  'bloodbath': 3,
#  'savage salvation': 1,
#  'exorcism schools': 1,
#  'spiritual battlefield': 1,
#  'sister ann': 1,
#  'young nun': 2,
#  'devil': 45,
#  'catholic church': 2,
#  'rite': 4,
#  'demonic possessions': 1,
#  'fellow student father dante': 1,
#  'global rise': 1,
#  'priests': 3,
#  'unlikely warrior rises': 1,
#  'response': 4,
#  'soul': 34,
#  'prey': 24,
#  'ana': 8,
#  'chef': 10,
#  'restaurant': 12,
#  'meticulous past': 1,
#  'turf': 4,
#  'knife skills': 1,
#  'local mafia': 2,
#  'high heat': 1,
#  'kitchen': 6,
#  'vendetta': 4,
#  'old enemies': 2,
#  'feisty daughter flee': 1,
#  'il mio nome': 2,
#  'milan': 2,
#  'family': 473,
#  'revenge': 176,
#  'father': 385,
#  'murder': 169,
#  'down on their luck assassins': 1,
#  'by the book female detective teams': 1,
#  'big': 19,
#  'wakanda': 5,
#  'war dog nakia': 1,
#  'queen ramonda': 1,
#  'shuri': 2,
#  'world powers': 2,
#  'everett ross': 1,
#  'dora milaje fight': 1,
#  'nation': 24,
#  'okoye': 2,
#  'help': 263,
#  'wake': 24,
#  'kingdom': 53,
#  'new path': 1,
#  'black panther': 3,
#  'death': 244,
#  'wakandans': 1,
#  'heroes': 33,
#  'grandmother': 24,
#  'home': 207,
#  'ojo': 1,
#  'nala': 2,
#  'thirteen year old girl': 1,
#  'little sister': 6,
#  'city': 148,
#  'countryside': 23,
#  'mal': 4,
#  'mysterious illness': 6,
#  'cure': 23,
#  'granny': 4,
#  'hollywood bowl': 1,
#  'encanto live to film concert experience': 1,
#  'original cast': 2,
#  'miracle': 9,
#  'concert': 7,
#  'performance': 6,
#  'favorite songs': 1,
#  'person ensemble': 1,
#  'encanto': 2,
#  'casita': 1,
#  'rooster toto': 1,
#  'new enemy': 5,
#  'pirate': 6,
#  'huevitos congelados': 1,
#  'mussolini': 2,
#  'fascism': 1,
#  'italy': 22,
#  'rise': 38,
#  'wooden boy': 1,
#  'pinocchio': 10,
#  'guillermo del toro': 3,
#  'expectations': 10,
#  'detective knight': 1,
#  'hot pursuit': 5,
#  'mask wearing armed robbers': 1,
#  'partner': 41,
#  'heist': 28,
#  'shootout': 7,
#  'halloween': 17,
#  'los angeles': 85,
#  'bandits': 6,
#  'rogue': 11,
#  'new york': 83,
#  'present case': 1,
#  'collides': 1,
#  'redemption': 29,
#  'ensa': 1,
#  'taizai': 1,
#  'britain': 13,
#  'peace': 63,
#  'edinburgh': 3,
#  'young prince': 3,
#  'evil forces': 8,
#  'nanatsu': 1,
#  'perilous journey': 11,
#  'ones': 21,
#  'true strength': 1,
#  'school': 110,
#  'job': 152,
#  'teacher': 24,
#  'best friend': 73,
#  'gang': 115,
#  'lekcji': 1,
#  'responsible': 31,
#  'consequential presidential election': 1,
#  'history': 76,
#  'legendary journalist nick booker': 1,
#  'idol': 11,
#  'fate': 88,
#  'america': 70,
#  'conspiracy': 30,
#  'country': 95,
#  'idealistic young journalist teams': 1,
#  'final weeks': 2,
#  'hands': 59,
#  'independent': 5,
#  'james cameron': 2,
#  'cast': 17,
#  'anticipated movie sequels': 1,
#  'deep dive': 1,
#  'inside look': 2,
#  'museum': 5,
#  'night': 198,
#  'kahmunrah': 1,
#  'nick daley': 1,
#  'footsteps': 10,
#  'natural history': 2,
#  'sun': 22,
#  '14th century czech icon': 1,
#  'warlord jan zizka': 1,
#  'armies': 6,
#  'teutonic order': 1,
#  'medieval': 1,
#  'holy roman empire': 1,
#  'returns': 22,
#  'earth': 256,
#  'special police force': 1,
#  'humanity': 74,
#  'sheriff roy pulsipher': 1,
#  'undead': 13,
#  'afterlife': 9,
#  'damned': 5,
#  'hunter': 11,
#  'best friends becky': 1,
#  'lack': 25,
#  'expert climbing skills': 1,
#  'supplies': 7,
#  'fears': 19,
#  'elements': 13,
#  'radio tower': 2,
#  'remote': 6,
#  'limits': 18,
#  'vertigo inducing heights': 1,
#  'feet': 22,
#  'ultimate test': 9,
#  'art': 30,
#  'clown returns': 1,
#  'younger brother': 15,
#  'true nature': 5,
#  'halloween night': 9,
#  'miles county': 1,
#  'sinister entity': 1,
#  'siblings': 18,
#  'evil intent': 1,
#  'body count': 12,
#  'teenage girl': 22,
#  'terrifier': 4,
#  'boss baby': 4,
#  'christmas bonus': 1,
#  'santa': 16,
#  'twisty turn': 1,
#  'elves': 9,
#  'places': 20,
#  'north pole': 11,
#  'skydivers': 1,
#  'group': 361,
#  'jump': 4,
#  'paranormal occurrences': 2,
#  'mysterious disappearance': 4,
#  'hex': 3,
#  'mykola': 1,
#  'pregnant wife': 10,
#  'senseless death': 1,
#  'sniper company': 1,
#  'donbass': 1,
#  'naive world': 1,
#  'war': 138,
#  'useful': 2,
#  'militants': 2,
#  'eccentric pacifist': 1,
#  'scar': 3,
#  'killers': 31,
#  'ground': 16,
#  'friend': 103,
#  'instructor': 4,
#  'beauty salon': 4,
#  'dae hye': 1,
#  'bikini service': 1,
#  'jackpot': 6,
#  'men': 177,
#  'women': 125,
#  'building owner': 1,
#  'relationship': 140,
#  'director': 20,
#  'rent pressure': 1,
#  'depression': 5,
#  'employee juhee': 1,
#  'difficult': 14,
#  'foreign country': 3,
#  'guests': 13,
#  'menu': 2,
#  'exclusive restaurant': 1,
#  'young couple': 22,
#  'remote island': 9,
#  'shocking surprises': 1,
#  'street smart kitty softpaws': 1,
#  'lover': 44,
#  'notorious fighter': 1,
#  'tough': 12,
#  'cat': 40,
#  'myth': 7,
#  'mastermind humpty dumpty': 1,
#  'hero': 43,
#  'true story': 82,
#  'legend': 46,
#  'town': 128,
#  'shrek': 9,
#  'maverick': 5,
#  'pete': 6,
#  'mitchell': 2,
#  'rank': 2,
#  'advancement': 1,
#  'specialized mission': 1,
#  'likes': 2,
#  'service': 10,
#  'detachment': 2,
#  'navy': 5,
#  'living pilot': 1,
#  'woman': 256,
#  'postpartum psychosis': 1,
#  'infant son': 3,
#  'remote farmhouse': 2,
#  'house': 194,
#  'secrets': 69,
#  'young couple moves': 1,
#  'traumatic incident': 1,
#  'rose': 9,
#  'troubling past': 2,
#  'bizarre': 11,
#  'order': 278,
#  'patient': 15,
#  'overwhelming terror': 1,
#  'frightening occurrences': 1,
#  'smile': 2,
#  'new reality': 3,
#  'small southern town': 4,
#  'sheriff thurmond fowler': 1,
#  'plot': 44,
#  'multiple murders': 1,
#  'next door neighbor': 5,
#  'stockbroker': 1,
#  'insurance scam': 3,
#  'host': 17,
#  'dead': 140,
#  'winds': 3,
#  'decades': 35,
#  'minute': 3,
#  'idyllic': 7,
#  'new': 38,
#  'remote sanctuary': 1,
#  'laura': 10,
#  'monstrous': 2,
#  'bigger': 3,
#  'seven year old son cody': 1,
#  'terrifying monster': 1,
#  'abusive relationship': 2,
#  'fingers': 3,
#  'freddy': 9,
#  'unrelenting california desert': 1,
#  'cash': 34,
#  'robbing': 1,
#  'run': 74,
#  'bus': 4,
#  'humankind': 21,
#  'centuries': 22,
#  'survival': 88,
#  'resources': 7,
#  'exodus': 4,
#  'outer space': 10,
#  'awry': 29,
#  'plans': 56,
#  'crew': 100,
#  'strange planet': 1,
#  'international expedition': 1,
#  'power': 120,
#  'suitable new planet': 1,
#  'unimaginable': 2,
#  'wait': 4,
#  'wooden puppet embarks': 1,
#  'thrilling adventure': 3,
#  'real boy': 5,
#  'alban dutertre teams': 1,
#  'officer brnice amarillo': 1,
#  'orlans research section': 1,
#  'suspicious position': 1,
#  'captain': 10,
#  'davinci': 1,
#  'tomb': 8,
#  'violinist': 2,
#  'puzzle': 4,
#  'andalasia': 1,
#  'future happiness': 3,
#  'magic': 43,
#  'real life fairy tale': 2,
#  'jeopardy': 14,
#  'giselle': 3,
#  'place': 136,
#  'suburbia': 4,
#  'easy': 23,
#  'time': 415,
#  'spell': 18,
#  'lyle': 2,
#  'new school': 7,
#  'crocodile': 4,
#  'primm family': 1,
#  'caviar': 1,
#  'baths': 2,
#  'great music': 1,
#  'attic': 12,
#  'new york city': 61,
#  'existence': 41,
#  'changes': 10,
#  'young son josh': 1,
#  'primms': 1,
#  'unexpected places': 2,
#  'untold fortune': 1,
#  'target': 42,
#  'cops': 34,
#  'mob': 22,
#  'race': 61,
#  'cryptocurrency': 1,
#  'bank heist': 4,
#  'master thief': 3,
#  'blowback': 1,
#  'peter parker': 8,
#  'doctor strange': 5,
#  'unmasked': 2,
#  'way home': 3,
#  'stakes': 11,
#  'spider man': 12,
#  'normal life': 7,
#  'high stakes': 4,
#  'able': 84,
#  'super hero': 2,
#  'dangerous': 35,
#  'iceland': 3,
#  'bank robberies': 1,
#  'bssi': 1,
#  'series': 169,
#  'toughest cop': 1,
#  'pressure': 17,
#  'new partner': 5,
#  'case': 90,
#  'leynilgga': 1,
#  'possible': 29,
#  'making of james cameron': 1,
#  'pandora': 6,
#  'interesting parts': 1,
#  'work': 104,
#  'set': 8,
#  'shelter': 21,
#  'hiker': 1,
#  'mountain lodge': 1,
#  'megan': 7,
#  'strange women': 1,
#  'isla nublar': 2,
#  'destruction': 48,
#  'biosyn operatives': 1,
#  'swarm': 1,
#  'maisie lockwood': 1,
#  'dr ellie sattler': 1,
#  'giant insects': 1,
#  'jurassic world dominion': 1,
#  'alcohol': 2,
#  'problems': 33,
#  'drugs': 36,
#  'loss': 44,
#  'son': 244,
#  'corps': 4,
#  'macarena gmez': 1,
#  'man': 415,
#  'policewoman': 2,
#  'popular tv actress': 1,
#  'polar': 3,
#  'horror festival': 1,
#  'jeepers creepers': 4,
#  'laine': 1,
#  'urban legend': 7,
#  'visions': 13,
#  'blood soaked entertainment': 1,
#  'boyfriend': 54,
#  'reborn': 4,
#  'frenzy': 2,
#  'center': 24,
#  'wealthy family': 7,
#  'leena klammer': 1,
#  'murderous': 2,
#  'child': 97,
#  'esther': 2,
#  'daughter': 218,
#  'estonian psychiatric facility': 1,
#  'mask': 13,
#  'mother': 277,
#  'cost': 24,
#  'orphan': 11,
#  'esther childhood': 1,
#  'fausto': 1,
#  'abras la puerta': 1,
#  'brother in law': 6,
#  'supernatural situation': 1,
#  'control': 91,
#  'patriotic fervour': 1,
#  'friends albert': 1,
#  'excitement': 15,
#  'romantic dreams': 1,
#  'paul baumer': 2,
#  'muller': 1,
#  'heroism': 4,
#  'german army': 3,
#  'boys': 42,
#  'westen nichts neues': 1,
#  'soul destroying horror': 2,
#  'god butcher': 1,
#  'thor': 6,
#  'king valkyrie': 1,
#  'korg': 1,
#  'love': 477,
#  'gorr': 1,
#  'extinction': 11,
#  'galactic killer': 1,
#  'thunder': 4,
#  'retirement': 26,
#  'jane foster': 2,
#  'mjolnir': 1,
#  'harrowing cosmic adventure': 1,
#  'vengeance': 63,
#  'scene deconstruction': 1,
#  'hawaiian crime world': 1,
#  'renegade bounty hunter ryan swan': 1,
#  'kingpin': 7,
#  'paradise city': 1,
#  'camp': 11,
#  'fierce': 6,
#  'danger': 56,
#  'skilled comanche warrior naru': 1,
#  'people': 209,
#  'alien predator': 2,
#  'advanced arsenal': 1,
#  'goku': 19,
#  'gamma': 1,
#  'mightier androids': 1,
#  'red ribbon army': 1,
#  'past': 177,
#  'evil organization': 1,
#  'buster': 3,
#  'glamorous redshore city': 1,
#  'ridiculous idea': 1,
#  'crystal tower theater': 1,
#  'ruthless wolf mogul jimmy crystal': 1,
#  'lion rock legend clay calloway': 1,
#  'crystal entertainment offices': 1,
#  'connections': 4,
#  'singers': 3,
#  'new cast': 1,
#  'quest': 96,
#  'now isolated clay': 1,
#  'sights': 20,
#  'stage': 12,
#  'boy': 116,
#  'boars': 1,
#  'head': 72,
#  'fire hashira': 1,
#  'demon': 14,
#  'zenitsu agatsuma': 1,
#  'kyjur rengoku': 1,
#  'new mission': 3,
#  'infinity train': 1,
#  'inosuke hashibira': 1,
#  'true power': 3,
#  'tanjir kamado': 1,
#  'game reserve': 2,
#  'south africa': 6,
#  'healing': 5,
#  'fight': 60,
#  'teenage daughters': 2,
#  'bloodthirsty lion': 1,
#  'beast': 23,
#  'sonic': 3,
#  'emerald': 1,
#  'knuckles': 3,
#  'search': 131,
#  'civilizations': 1,
#  'green hills': 1,
#  'eager': 15,
#  'test': 21,
#  'true hero': 3,
#  'hedgehog': 3,
#  'globe trotting journey': 1,
#  'tails': 3,
#  'wrong hands': 4,
#  'endurance': 3,
#  'freedom': 50,
#  'emancipation': 1,
#  'cadet': 1,
#  'west point': 1,
#  'strange': 28,
#  'brilliant young fellow': 1,
#  'reluctant detective': 1,
#  'pale blue eye': 1,
#  'grisly mystery': 1,
#  'military academy': 1,
#  'edgar allan poe': 2,
#  'heart': 103,
#  'unlucky assassin ladybug': 1,
#  'bullet train': 1,
#  'collision course': 13,
#  'latest mission': 1,
#  'determined': 80,
#  'lethal adversaries': 1,
#  'rails': 2,
#  'conflicting': 1,
#  'guardians': 14,
#  'christmas unforgettable': 1,
#  'quill': 1,
#  'galaxy holiday special': 1,
#  'perfect present': 2,
#  'vacation': 40,
#  'island paradise': 3,
#  'unrelenting great white': 1,
#  'maneater': 1,
#  'accident': 48,
#  'military leave promises': 1,
#  'female sniper': 1,
#  'fianc': 24,
#  'wish': 18,
#  'alien sniperess': 1,
#  'hostile alien invasion': 1,
#  'countless lives': 3,
#  'rodrick rules': 2,
#  'wimpy kid': 6,
#  'new school year': 2,
#  'diary': 13,
#  'greg': 5,
#  'secret ruin': 1,
#  'half human': 5,
#  'deadly man made creatures': 1,
#  'ravagers': 2,
#  'half alien': 1,
#  'underground bunker': 2,
#  'hungry': 10,
#  'afghanistan': 16,
#  'dangerous rebel strongholds': 1,
#  'refuge': 37,
#  'human flesh': 6,
#  'final flight mission': 1,
#  'jet': 5,
#  'kate sinclair': 1,
#  'lair': 8,
#  'emily': 12,
#  'income': 3,
#  'desperate': 63,
#  'shady gig': 1,
#  'criminal': 18,
#  'goods': 5,
#  'charismatic middleman': 1,
#  'credit cards': 1,
#  'youcef': 1,
#  'quick cash': 3,
#  'illicit thrills': 1,
#  'plan': 85,
#  'business': 48,
#  'ronin': 5,
#  'new class': 1,
#  'samurai clans': 1,
#  'sequel': 30,
#  'sought after sword': 1,
#  'blade': 5,
#  'family reunion': 2,
#  'remote mansion': 2,
#  'legacy murders': 1,
#  'lethal turn': 1,
#  'dangerous game': 9,
#  'deadly survival game': 1,
#  'selfish miser ebenezer scrooge': 1,
#  'cold christmas eve': 1,
#  'christmas carol': 8,
#  'future': 118,
#  'scrooge': 3,
#  'initial efforts': 1,
#  'unsuccessful': 2,
#  'roger': 5,
#  'erotic drama': 1,
#  'world war': 9,
#  'virginity': 12,
#  'jerry snowman': 1,
#  'tom': 26,
#  'tuffy': 1,
#  'snow mouse': 1,
#  'larry': 5,
#  'air': 26,
#  'nephew': 12,
#  'holiday spirit': 1,
#  'village': 51,
#  'fabled snowman': 1,
#  'nathan drake': 1,
#  'sully': 3,
#  'sullivan embark': 1,
#  'partner victor': 1,
#  'young street smart': 1,
#  'dangerous pursuit': 1,
#  'greatest treasure': 1,
#  'long lost brother': 1,
#  'clues': 24,
#  'gru': 3,
#  'minions': 8,
#  'fanboy': 1,
#  'supervillain supergroup': 1,
#  'vicious': 8,
#  'evil': 71,
#  'followers': 12,
#  'backup': 1,
#  'luck': 16,
#  'unluckiest person': 1,
#  'never before seen land': 1,
#  'magical creatures': 3,
#  'toe': 3,
#  'kurt': 4,
#  'firm': 8,
#  'legendary beauty salon': 1,
#  'special technique': 1,
#  'male guests': 1,
#  'sure': 23,
#  'hair salon': 2,
#  'beauty parlor': 1,
#  'good': 68,
#  'financial difficulties': 1,
#  'regular': 4,
#  'multiverse': 6,
#  'mystical allies': 1,
#  'old': 24,
#  'madness': 21,
#  'dangerous alternate realities': 1,
#  'mind bending': 1,
#  'mind': 47,
#  'goal': 30,
#  'corrupt cops': 4,
#  'brother': 87,
#  'genius mechanic lino': 1,
#  'mentor': 22,
#  'balle perdue': 2,
#  'batman': 44,
#  'corruption': 19,
#  'crime': 83,
#  'gotham city': 16,
#  'second year': 5,
#  'serial killer': 37,
#  'riddler': 3,
#  'bora': 1,
#  'best friend bora': 1,
#  'baek hyun jin': 1,
#  'close': 31,
#  'pung woon ho': 1,
#  'clumsy plan': 1,
#  'new century': 3,
#  'heart surgery': 2,
#  'unexpected direction': 1,
#  'year': 114,
#  'information': 19,
#  '20 ': 1,
#  'fever': 1,
#  'magical house': 1,
#  'mirabel': 1,
#  'extraordinary family': 1,
#  'charmed place': 1,
#  'wondrous': 2,
#  'colombia': 6,
#  'mountains': 20,
#  'vibrant town': 1,
#  'madrigals': 1,
#  'tale': 41,
#  'renowned psychologist susanne': 1,
#  'new client': 3,
#  'signe egholm olsen': 1,
#  'anton hjejle': 1,
#  'nightmare': 42,
#  'klienten': 1,
#  'wanted serial killer': 1,
#  'iraq': 13,
#  'searches': 4,
#  'tours': 2,
#  'louisiana': 5,
#  'unknown woman': 3,
#  'marine': 7,
#  'good luck charm': 3,
#  'lucky': 11,
#  'criminals': 49,
#  'engulfs': 3,
#  'treacherous': 5,
#  'inmates': 5,
#  'prison': 97,
#  'dangerous maximum security penitentiary': 1,
#  'tensions': 23,
#  'staff': 13,
#  'anarchy': 5,
#  'san tiburon': 1,
#  'corrective measures': 1,
#  'ancient puzzle box': 1,
#  'unaware': 33,
#  'sadistic supernatural beings': 1,
#  'possession': 29,
#  'purpose': 21,
#  'cenobites': 2,
#  'young woman': 95,
#  'hellraiser': 9,
#  'dimension': 5,
#  'broadway musical': 2,
#  'josh': 6,
#  'blue': 9,
#  'rainbow puppy': 1,
#  'opportunity': 43,
#  'nyc': 4,
#  'lifetime': 39,
#  'big city adventure': 1,
#  'dance': 14,
#  'new friends': 20,
#  'dreams': 115,
#  'mouse': 18,
#  'edgy radio host': 1,
#  'provocative': 2,
#  'mysterious caller': 1,
#  'line': 40,
#  'summit fever': 1,
#  'deadly storm': 2,
#  'challenging trio': 1,
#  'climbers': 3,
#  'hope': 60,
#  'rescue': 36,
#  'terrifying nightmare': 2,
#  'dream': 61,
#  'means necessary': 7,
#  'glimpse': 7,
#  'bullied overweight teenager': 1,
#  'tormentors': 3,
#  'cerdita': 1,
#  'mesmerizing stranger': 1,
#  'teenagers': 43,
#  'zombie apocalypse': 6,
#  'mexzombies': 1,
#  'dangerous conspiracy ignite': 1,
#  'enola holmes': 2,
#  'sparks': 5,
#  'infamous brother': 1,
#  'girl': 146,
#  'red': 12,
#  'thirteen year old mei': 1,
#  'teenager': 42,
#  'awkwardness': 2,
#  'twist': 8,
#  'excited': 10,
#  'sophia': 3,
#  'french lyce': 1,
#  'barcelona': 11,
#  'rough middle school': 1,
#  'horrible work conditions': 1,
#  'well ': 1,
#  'hopes': 45,
#  'over qualified teacher': 1,
#  'ecstatic': 4,
#  'new life teaching': 1,
#  'bits': 3,
#  'position': 18,
#  'thankless teaching job': 1,
#  'upscale paris school': 1,
#  'competitor': 3,
#  'long awaited transfer': 1,
#  'candidacy': 1,
#  'elric brothers': 3,
#  'long': 21,
#  'epic finale': 1,
#  'unworldly': 1,
#  'nationwide threat': 1,
#  'friends mummy': 1,
#  'jeff': 3,
#  'la tabla esmeralda': 1,
#  'tad': 3,
#  'ancient spell': 2,
#  'belzoni': 1,
#  'curse': 40,
#  'tadeo jones': 2,
#  'sara': 14,
#  'unexplained circumstances': 1,
#  'youngest brother': 1,
#  'tragic death': 5,
#  'hours': 40,
#  'athena': 5,
#  'insane adventure': 1,
#  'important': 10,
#  'chinese immigrant': 2,
#  'fame': 32,
#  'sexual wellness company': 1,
#  'onetaste': 1,
#  'members': 39,
#  'orgasm inc': 1,
#  'shocking allegations': 1,
#  'helen': 5,
#  'forest': 32,
#  'family camping trip': 1,
#  'father stan': 1,
#  'daughter emily': 1,
#  'disturbing secret': 2,
#  'property': 17,
#  'real outdoors experience': 1,
#  'angry landowner howard arrive': 1,
#  'weird al': 1,
#  'all star athletes zlatan ibrahimovi': 1,
#  'evil scientist': 2,
#  'yankovic': 1,
#  'soccer balls': 1,
#  'megan rapinoe': 1,
#  'biggest fans': 1,
#  'mysterious green slime monsters': 1,
#  'talent': 19,
#  'soccer football movie': 1,
#  'childhood friend rika': 1,
#  ...}

# %%
# We also define a function to play around and see with which movies one topic is associated with.
# Ultimately, this is just a POC, but we will later use RDF for our final application.

def search_keyword(keyword):
    if keyword in topics:
        print(f'{str(topics[keyword])} results found for "{keyword}"')
        print("------------------------------------------------------")
        for movie in movies:
            if keyword in movie["topics"]:
                print(movie['title'])

# %%
search_keyword('beasts')
# Out:
# 4 results found for "beasts"
# ------------------------------------------------------
# Transformers: Rise of the Beasts
# Beasts of No Nation
# Dragon Nest: Warriors' Dawn
# L.O.R.D: Legend of Ravaging Dynasties

# %%
all_topics = []
for topic in topics:
    t_ = re.sub(r'[^a-zA-Z0-9 ]', '', topic)
    if t_.replace(' ', ''):
        all_topics.append(t_)

with open("all_topics.txt", "w") as f:
    f.write('\n'.join(all_topics))
all_topics_set = set(all_topics)
all_topics
# Out:
# ['puss',
#  'boots',
#  'passion',
#  'adventure',
#  'lives',
#  'toll',
#  'life',
#  'epic journey',
#  'jake',
#  'sully family',
#  'neytiri',
#  'way',
#  'water',
#  'kids',
#  'story',
#  'decade',
#  'events',
#  'trouble',
#  'avatar',
#  'alive',
#  'lengths',
#  'battles',
#  'tragedies',
#  'team',
#  'wealthy family compound',
#  'christmas eve',
#  'santa claus',
#  'mercenaries',
#  'surprise combatant',
#  'hostage',
#  'grounds',
#  'nick',
#  'violent night',
#  'saint',
#  'life like doll',
#  'm3gan',
#  'artificial intelligence',
#  'new friend',
#  'brilliant toy company roboticist',
#  'programming works',
#  'overprotective',
#  'terrifying results',
#  'niece',
#  'narnia',
#  'witch',
#  'lion',
#  'wardrobe',
#  'siblings lucy',
#  'edmund',
#  'susan',
#  'children',
#  'aslan',
#  'climactic battle',
#  'spectacular',
#  'peter',
#  'wise',
#  'jadis',
#  'land',
#  'free',
#  'eternal winter',
#  'peaceful kingdom',
#  'charming',
#  'glacial powers',
#  'dovre',
#  'mountain',
#  'capital',
#  'creature',
#  'norway',
#  'gigantic awakens',
#  'path',
#  'years',
#  'troll',
#  'norwegian folklore',
#  'unique form',
#  'justice',
#  'ready',
#  'earthly tomb',
#  'modern world',
#  'black adam',
#  'almighty powers',
#  'mystery',
#  'world famous detective benoit blanc',
#  'knives',
#  'eclectic crew',
#  'tech billionaire',
#  'layers',
#  'greece',
#  'friends',
#  'glass onion',
#  'paraplegic marine',
#  'moon pandora',
#  '22nd century',
#  'unique mission',
#  'orders',
#  'alien civilization',
#  '1800s',
#  'dahomey',
#  'skills',
#  'african kingdom',
#  'all female unit',
#  'warriors',
#  'fierceness',
#  'agojie',
#  'world',
#  'enemy',
#  'battle',
#  'woman king',
#  'general nanisca',
#  'recruits',
#  'treacherous land',
#  'uncharted',
#  'differences',
#  'explorers',
#  'fantastical creatures',
#  'journey',
#  'crucial',
#  'mission',
#  'latest',
#  'strange world',
#  'summons',
#  'superpower',
#  'matilda',
#  'remarkable courage',
#  'extraordinary young girl',
#  'musical',
#  'roald dahl',
#  'odds',
#  'stories',
#  'charge',
#  'right',
#  'miraculous results',
#  'shelby john',
#  'struggles',
#  'vigilante justice',
#  'addiction',
#  'end',
#  'nail gun',
#  'fresh start',
#  'ruby red',
#  'beloved ruby dead',
#  'sheriff church',
#  'crime lord coyote',
#  'vengeful killing spree',
#  'porch',
#  'clock',
#  'entire town',
#  'adrenaline',
#  'dealers',
#  'chaos',
#  'bloodbath',
#  'savage salvation',
#  'exorcism schools',
#  'spiritual battlefield',
#  'sister ann',
#  'young nun',
#  'devil',
#  'catholic church',
#  'rite',
#  'demonic possessions',
#  'fellow student father dante',
#  'global rise',
#  'priests',
#  'unlikely warrior rises',
#  'response',
#  'soul',
#  'prey',
#  'ana',
#  'chef',
#  'restaurant',
#  'meticulous past',
#  'turf',
#  'knife skills',
#  'local mafia',
#  'high heat',
#  'kitchen',
#  'vendetta',
#  'old enemies',
#  'feisty daughter flee',
#  'il mio nome',
#  'milan',
#  'family',
#  'revenge',
#  'father',
#  'murder',
#  'down on their luck assassins',
#  'by the book female detective teams',
#  'big',
#  'wakanda',
#  'war dog nakia',
#  'queen ramonda',
#  'shuri',
#  'world powers',
#  'everett ross',
#  'dora milaje fight',
#  'nation',
#  'okoye',
#  'help',
#  'wake',
#  'kingdom',
#  'new path',
#  'black panther',
#  'death',
#  'wakandans',
#  'heroes',
#  'grandmother',
#  'home',
#  'ojo',
#  'nala',
#  'thirteen year old girl',
#  'little sister',
#  'city',
#  'countryside',
#  'mal',
#  'mysterious illness',
#  'cure',
#  'granny',
#  'hollywood bowl',
#  'encanto live to film concert experience',
#  'original cast',
#  'miracle',
#  'concert',
#  'performance',
#  'favorite songs',
#  'person ensemble',
#  'encanto',
#  'casita',
#  'rooster toto',
#  'new enemy',
#  'pirate',
#  'huevitos congelados',
#  'mussolini',
#  'fascism',
#  'italy',
#  'rise',
#  'wooden boy',
#  'pinocchio',
#  'guillermo del toro',
#  'expectations',
#  'detective knight',
#  'hot pursuit',
#  'mask wearing armed robbers',
#  'partner',
#  'heist',
#  'shootout',
#  'halloween',
#  'los angeles',
#  'bandits',
#  'rogue',
#  'new york',
#  'present case',
#  'collides',
#  'redemption',
#  'ensa',
#  'taizai',
#  'britain',
#  'peace',
#  'edinburgh',
#  'young prince',
#  'evil forces',
#  'nanatsu',
#  'perilous journey',
#  'ones',
#  'true strength',
#  'school',
#  'job',
#  'teacher',
#  'best friend',
#  'gang',
#  'lekcji',
#  'responsible',
#  'consequential presidential election',
#  'history',
#  'legendary journalist nick booker',
#  'idol',
#  'fate',
#  'america',
#  'conspiracy',
#  'country',
#  'idealistic young journalist teams',
#  'final weeks',
#  'hands',
#  'independent',
#  'james cameron',
#  'cast',
#  'anticipated movie sequels',
#  'deep dive',
#  'inside look',
#  'museum',
#  'night',
#  'kahmunrah',
#  'nick daley',
#  'footsteps',
#  'natural history',
#  'sun',
#  '14th century czech icon',
#  'warlord jan zizka',
#  'armies',
#  'teutonic order',
#  'medieval',
#  'holy roman empire',
#  'returns',
#  'earth',
#  'special police force',
#  'humanity',
#  'sheriff roy pulsipher',
#  'undead',
#  'afterlife',
#  'damned',
#  'hunter',
#  'best friends becky',
#  'lack',
#  'expert climbing skills',
#  'supplies',
#  'fears',
#  'elements',
#  'radio tower',
#  'remote',
#  'limits',
#  'vertigo inducing heights',
#  'feet',
#  'ultimate test',
#  'art',
#  'clown returns',
#  'younger brother',
#  'true nature',
#  'halloween night',
#  'miles county',
#  'sinister entity',
#  'siblings',
#  'evil intent',
#  'body count',
#  'teenage girl',
#  'terrifier',
#  'boss baby',
#  'christmas bonus',
#  'santa',
#  'twisty turn',
#  'elves',
#  'places',
#  'north pole',
#  'skydivers',
#  'group',
#  'jump',
#  'paranormal occurrences',
#  'mysterious disappearance',
#  'hex',
#  'mykola',
#  'pregnant wife',
#  'senseless death',
#  'sniper company',
#  'donbass',
#  'naive world',
#  'war',
#  'useful',
#  'militants',
#  'eccentric pacifist',
#  'scar',
#  'killers',
#  'ground',
#  'friend',
#  'instructor',
#  'beauty salon',
#  'dae hye',
#  'bikini service',
#  'jackpot',
#  'men',
#  'women',
#  'building owner',
#  'relationship',
#  'director',
#  'rent pressure',
#  'depression',
#  'employee juhee',
#  'difficult',
#  'foreign country',
#  'guests',
#  'menu',
#  'exclusive restaurant',
#  'young couple',
#  'remote island',
#  'shocking surprises',
#  'street smart kitty softpaws',
#  'lover',
#  'notorious fighter',
#  'tough',
#  'cat',
#  'myth',
#  'mastermind humpty dumpty',
#  'hero',
#  'true story',
#  'legend',
#  'town',
#  'shrek',
#  'maverick',
#  'pete',
#  'mitchell',
#  'rank',
#  'advancement',
#  'specialized mission',
#  'likes',
#  'service',
#  'detachment',
#  'navy',
#  'living pilot',
#  'woman',
#  'postpartum psychosis',
#  'infant son',
#  'remote farmhouse',
#  'house',
#  'secrets',
#  'young couple moves',
#  'traumatic incident',
#  'rose',
#  'troubling past',
#  'bizarre',
#  'order',
#  'patient',
#  'overwhelming terror',
#  'frightening occurrences',
#  'smile',
#  'new reality',
#  'small southern town',
#  'sheriff thurmond fowler',
#  'plot',
#  'multiple murders',
#  'next door neighbor',
#  'stockbroker',
#  'insurance scam',
#  'host',
#  'dead',
#  'winds',
#  'decades',
#  'minute',
#  'idyllic',
#  'new',
#  'remote sanctuary',
#  'laura',
#  'monstrous',
#  'bigger',
#  'seven year old son cody',
#  'terrifying monster',
#  'abusive relationship',
#  'fingers',
#  'freddy',
#  'unrelenting california desert',
#  'cash',
#  'robbing',
#  'run',
#  'bus',
#  'humankind',
#  'centuries',
#  'survival',
#  'resources',
#  'exodus',
#  'outer space',
#  'awry',
#  'plans',
#  'crew',
#  'strange planet',
#  'international expedition',
#  'power',
#  'suitable new planet',
#  'unimaginable',
#  'wait',
#  'wooden puppet embarks',
#  'thrilling adventure',
#  'real boy',
#  'alban dutertre teams',
#  'officer brnice amarillo',
#  'orlans research section',
#  'suspicious position',
#  'captain',
#  'davinci',
#  'tomb',
#  'violinist',
#  'puzzle',
#  'andalasia',
#  'future happiness',
#  'magic',
#  'real life fairy tale',
#  'jeopardy',
#  'giselle',
#  'place',
#  'suburbia',
#  'easy',
#  'time',
#  'spell',
#  'lyle',
#  'new school',
#  'crocodile',
#  'primm family',
#  'caviar',
#  'baths',
#  'great music',
#  'attic',
#  'new york city',
#  'existence',
#  'changes',
#  'young son josh',
#  'primms',
#  'unexpected places',
#  'untold fortune',
#  'target',
#  'cops',
#  'mob',
#  'race',
#  'cryptocurrency',
#  'bank heist',
#  'master thief',
#  'blowback',
#  'peter parker',
#  'doctor strange',
#  'unmasked',
#  'way home',
#  'stakes',
#  'spider man',
#  'normal life',
#  'high stakes',
#  'able',
#  'super hero',
#  'dangerous',
#  'iceland',
#  'bank robberies',
#  'bssi',
#  'series',
#  'toughest cop',
#  'pressure',
#  'new partner',
#  'case',
#  'leynilgga',
#  'possible',
#  'making of james cameron',
#  'pandora',
#  'interesting parts',
#  'work',
#  'set',
#  'shelter',
#  'hiker',
#  'mountain lodge',
#  'megan',
#  'strange women',
#  'isla nublar',
#  'destruction',
#  'biosyn operatives',
#  'swarm',
#  'maisie lockwood',
#  'dr ellie sattler',
#  'giant insects',
#  'jurassic world dominion',
#  'alcohol',
#  'problems',
#  'drugs',
#  'loss',
#  'son',
#  'corps',
#  'macarena gmez',
#  'man',
#  'policewoman',
#  'popular tv actress',
#  'polar',
#  'horror festival',
#  'jeepers creepers',
#  'laine',
#  'urban legend',
#  'visions',
#  'blood soaked entertainment',
#  'boyfriend',
#  'reborn',
#  'frenzy',
#  'center',
#  'wealthy family',
#  'leena klammer',
#  'murderous',
#  'child',
#  'esther',
#  'daughter',
#  'estonian psychiatric facility',
#  'mask',
#  'mother',
#  'cost',
#  'orphan',
#  'esther childhood',
#  'fausto',
#  'abras la puerta',
#  'brother in law',
#  'supernatural situation',
#  'control',
#  'patriotic fervour',
#  'friends albert',
#  'excitement',
#  'romantic dreams',
#  'paul baumer',
#  'muller',
#  'heroism',
#  'german army',
#  'boys',
#  'westen nichts neues',
#  'soul destroying horror',
#  'god butcher',
#  'thor',
#  'king valkyrie',
#  'korg',
#  'love',
#  'gorr',
#  'extinction',
#  'galactic killer',
#  'thunder',
#  'retirement',
#  'jane foster',
#  'mjolnir',
#  'harrowing cosmic adventure',
#  'vengeance',
#  'scene deconstruction',
#  'hawaiian crime world',
#  'renegade bounty hunter ryan swan',
#  'kingpin',
#  'paradise city',
#  'camp',
#  'fierce',
#  'danger',
#  'skilled comanche warrior naru',
#  'people',
#  'alien predator',
#  'advanced arsenal',
#  'goku',
#  'gamma',
#  'mightier androids',
#  'red ribbon army',
#  'past',
#  'evil organization',
#  'buster',
#  'glamorous redshore city',
#  'ridiculous idea',
#  'crystal tower theater',
#  'ruthless wolf mogul jimmy crystal',
#  'lion rock legend clay calloway',
#  'crystal entertainment offices',
#  'connections',
#  'singers',
#  'new cast',
#  'quest',
#  'now isolated clay',
#  'sights',
#  'stage',
#  'boy',
#  'boars',
#  'head',
#  'fire hashira',
#  'demon',
#  'zenitsu agatsuma',
#  'kyjur rengoku',
#  'new mission',
#  'infinity train',
#  'inosuke hashibira',
#  'true power',
#  'tanjir kamado',
#  'game reserve',
#  'south africa',
#  'healing',
#  'fight',
#  'teenage daughters',
#  'bloodthirsty lion',
#  'beast',
#  'sonic',
#  'emerald',
#  'knuckles',
#  'search',
#  'civilizations',
#  'green hills',
#  'eager',
#  'test',
#  'true hero',
#  'hedgehog',
#  'globe trotting journey',
#  'tails',
#  'wrong hands',
#  'endurance',
#  'freedom',
#  'emancipation',
#  'cadet',
#  'west point',
#  'strange',
#  'brilliant young fellow',
#  'reluctant detective',
#  'pale blue eye',
#  'grisly mystery',
#  'military academy',
#  'edgar allan poe',
#  'heart',
#  'unlucky assassin ladybug',
#  'bullet train',
#  'collision course',
#  'latest mission',
#  'determined',
#  'lethal adversaries',
#  'rails',
#  'conflicting',
#  'guardians',
#  'christmas unforgettable',
#  'quill',
#  'galaxy holiday special',
#  'perfect present',
#  'vacation',
#  'island paradise',
#  'unrelenting great white',
#  'maneater',
#  'accident',
#  'military leave promises',
#  'female sniper',
#  'fianc',
#  'wish',
#  'alien sniperess',
#  'hostile alien invasion',
#  'countless lives',
#  'rodrick rules',
#  'wimpy kid',
#  'new school year',
#  'diary',
#  'greg',
#  'secret ruin',
#  'half human',
#  'deadly man made creatures',
#  'ravagers',
#  'half alien',
#  'underground bunker',
#  'hungry',
#  'afghanistan',
#  'dangerous rebel strongholds',
#  'refuge',
#  'human flesh',
#  'final flight mission',
#  'jet',
#  'kate sinclair',
#  'lair',
#  'emily',
#  'income',
#  'desperate',
#  'shady gig',
#  'criminal',
#  'goods',
#  'charismatic middleman',
#  'credit cards',
#  'youcef',
#  'quick cash',
#  'illicit thrills',
#  'plan',
#  'business',
#  'ronin',
#  'new class',
#  'samurai clans',
#  'sequel',
#  'sought after sword',
#  'blade',
#  'family reunion',
#  'remote mansion',
#  'legacy murders',
#  'lethal turn',
#  'dangerous game',
#  'deadly survival game',
#  'selfish miser ebenezer scrooge',
#  'cold christmas eve',
#  'christmas carol',
#  'future',
#  'scrooge',
#  'initial efforts',
#  'unsuccessful',
#  'roger',
#  'erotic drama',
#  'world war',
#  'virginity',
#  'jerry snowman',
#  'tom',
#  'tuffy',
#  'snow mouse',
#  'larry',
#  'air',
#  'nephew',
#  'holiday spirit',
#  'village',
#  'fabled snowman',
#  'nathan drake',
#  'sully',
#  'sullivan embark',
#  'partner victor',
#  'young street smart',
#  'dangerous pursuit',
#  'greatest treasure',
#  'long lost brother',
#  'clues',
#  'gru',
#  'minions',
#  'fanboy',
#  'supervillain supergroup',
#  'vicious',
#  'evil',
#  'followers',
#  'backup',
#  'luck',
#  'unluckiest person',
#  'never before seen land',
#  'magical creatures',
#  'toe',
#  'kurt',
#  'firm',
#  'legendary beauty salon',
#  'special technique',
#  'male guests',
#  'sure',
#  'hair salon',
#  'beauty parlor',
#  'good',
#  'financial difficulties',
#  'regular',
#  'multiverse',
#  'mystical allies',
#  'old',
#  'madness',
#  'dangerous alternate realities',
#  'mind bending',
#  'mind',
#  'goal',
#  'corrupt cops',
#  'brother',
#  'genius mechanic lino',
#  'mentor',
#  'balle perdue',
#  'batman',
#  'corruption',
#  'crime',
#  'gotham city',
#  'second year',
#  'serial killer',
#  'riddler',
#  'bora',
#  'best friend bora',
#  'baek hyun jin',
#  'close',
#  'pung woon ho',
#  'clumsy plan',
#  'new century',
#  'heart surgery',
#  'unexpected direction',
#  'year',
#  'information',
#  '20 ',
#  'fever',
#  'magical house',
#  'mirabel',
#  'extraordinary family',
#  'charmed place',
#  'wondrous',
#  'colombia',
#  'mountains',
#  'vibrant town',
#  'madrigals',
#  'tale',
#  'renowned psychologist susanne',
#  'new client',
#  'signe egholm olsen',
#  'anton hjejle',
#  'nightmare',
#  'klienten',
#  'wanted serial killer',
#  'iraq',
#  'searches',
#  'tours',
#  'louisiana',
#  'unknown woman',
#  'marine',
#  'good luck charm',
#  'lucky',
#  'criminals',
#  'engulfs',
#  'treacherous',
#  'inmates',
#  'prison',
#  'dangerous maximum security penitentiary',
#  'tensions',
#  'staff',
#  'anarchy',
#  'san tiburon',
#  'corrective measures',
#  'ancient puzzle box',
#  'unaware',
#  'sadistic supernatural beings',
#  'possession',
#  'purpose',
#  'cenobites',
#  'young woman',
#  'hellraiser',
#  'dimension',
#  'broadway musical',
#  'josh',
#  'blue',
#  'rainbow puppy',
#  'opportunity',
#  'nyc',
#  'lifetime',
#  'big city adventure',
#  'dance',
#  'new friends',
#  'dreams',
#  'mouse',
#  'edgy radio host',
#  'provocative',
#  'mysterious caller',
#  'line',
#  'summit fever',
#  'deadly storm',
#  'challenging trio',
#  'climbers',
#  'hope',
#  'rescue',
#  'terrifying nightmare',
#  'dream',
#  'means necessary',
#  'glimpse',
#  'bullied overweight teenager',
#  'tormentors',
#  'cerdita',
#  'mesmerizing stranger',
#  'teenagers',
#  'zombie apocalypse',
#  'mexzombies',
#  'dangerous conspiracy ignite',
#  'enola holmes',
#  'sparks',
#  'infamous brother',
#  'girl',
#  'red',
#  'thirteen year old mei',
#  'teenager',
#  'awkwardness',
#  'twist',
#  'excited',
#  'sophia',
#  'french lyce',
#  'barcelona',
#  'rough middle school',
#  'horrible work conditions',
#  'well ',
#  'hopes',
#  'over qualified teacher',
#  'ecstatic',
#  'new life teaching',
#  'bits',
#  'position',
#  'thankless teaching job',
#  'upscale paris school',
#  'competitor',
#  'long awaited transfer',
#  'candidacy',
#  'elric brothers',
#  'long',
#  'epic finale',
#  'unworldly',
#  'nationwide threat',
#  'friends mummy',
#  'jeff',
#  'la tabla esmeralda',
#  'tad',
#  'ancient spell',
#  'belzoni',
#  'curse',
#  'tadeo jones',
#  'sara',
#  'unexplained circumstances',
#  'youngest brother',
#  'tragic death',
#  'hours',
#  'athena',
#  'insane adventure',
#  'important',
#  'chinese immigrant',
#  'fame',
#  'sexual wellness company',
#  'onetaste',
#  'members',
#  'orgasm inc',
#  'shocking allegations',
#  'helen',
#  'forest',
#  'family camping trip',
#  'father stan',
#  'daughter emily',
#  'disturbing secret',
#  'property',
#  'real outdoors experience',
#  'angry landowner howard arrive',
#  'weird al',
#  'all star athletes zlatan ibrahimovi',
#  'evil scientist',
#  'yankovic',
#  'soccer balls',
#  'megan rapinoe',
#  'biggest fans',
#  'mysterious green slime monsters',
#  'talent',
#  'soccer football movie',
#  'childhood friend rika',
#  ...]

# %%
def find_similar_topics_2(topic, all_topics_):
    similar_topics = []
    for topic_tested in all_topics_:
        if topic_tested in (topic+'s', topic+topic[-1]+'y'):
            similar_topics.append(topic_tested)
    return similar_topics

def find_similar_topics(topic, all_topics_): # Much faster
    similar_topics = []
    for tested_topic in (topic+'s', topic+topic[-1]+'y'):
        if tested_topic in all_topics_:
            similar_topics.append(tested_topic)
    return similar_topics

k = 'sun'
#search_keyword(k)
find_similar_topics(k, all_topics_set)
# Out:
# ['sunny']

# %% [markdown]
# ## Lifting Topics to RDF
# We will now lift our data to RDF, precisely our Topics, so we will later be able to link movies to each others from those topics. For that, we have to create a vocabulary that will allow this interoperability.

# %%
ttl_header = """@prefix owl: <http://www.w3.org/2002/07/owl#> .
@prefix skos: <http://www.w3.org/2004/02/skos/core#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix : <http://myvocab.org/> .

:Topic a skos:Concept ;
    skos:prefLabel "Topic"@en ;
    rdfs:label "Topic"@en ;
    skos:definition "A subject or area of interest or discussion."@en .

:similarTo a owl:SymmetricProperty ;
    rdfs:label "similar to"@en ;
    rdfs:comment "A word that is similar to another in terms of meaning and construction."@en ;
    rdfs:domain :Topic ;
    rdfs:range :Topic .
    
:relevance a owl:DatatypeProperty ;
    rdfs:label "relevance"@en ;
    rdfs:comment "relevance of a topic based on its specificity. The more semantically complex the more relevant."@en ;
    rdfs:domain :Topic ;
    rdfs:range xsd:integer .
"""

# %%
def format_str(string: str, **kwargs):
    for key, value in kwargs.items():
        string = string.replace('{{ '+key+' }}', str(value))
    return string

def to_camel_case(string):
    string = string.replace('-', ' ')
    words = string.split(" ")
    camel_case = ""
    for word in words[:]:
        camel_case += word.capitalize()
    return camel_case


def topic_to_rdf(topic, related_topics):
    text = ''':{{ ressource_name }} a :Topic ;
    skos:prefLabel "{{ topic }}"@en ;
    :relevance {{ relevance }}'''
    rdf = format_str(text,
                     ressource_name=to_camel_case(topic),
                     topic=topic,
                     relevance=len(topic.split(' ')))
    if related_topics:
        rdf += ' ;\n    :similarTo '+', '.join(map(lambda x: ':'+to_camel_case(x), related_topics))
    return rdf+" . \n\n"

print(topic_to_rdf("fun", ["funny"]))
# Out:
# :Fun a :Topic ;
#     skos:prefLabel "fun"@en ;
#     :relevance 1 ;
#     :similarTo :Funny .

# %%
ttl_body = ttl_header
for topic in tqdm(all_topics_set):
    ttl_body += topic_to_rdf(topic, find_similar_topics(topic, all_topics_set))
    
# Saving the ttl file.
f = open("topics.ttl", "w", encoding="utf-8")
f.write(ttl_body)
f.close()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 49701/49701 [00:01<00:00, 36116.80it/s]

# %%
# Saving the ttl file.
f = open("topics.ttl", "w", encoding="utf-8")
f.write(ttl_body)
f.close()

# %% [markdown]
# ## Interact with the system
# Now, let us play around using our ontology to get recommended movies.

# %%
print("--------------------------------------------------------------")
print("----------------------- FILMOWLEDGE CLI ----------------------")
print("--------------------------------------------------------------")
print()
print("Please describe what kind of movies you are looking for today:")
textual_search = input()
print()
print("--------------------------------------------------------------")
print("Voici quelques suggestions de films pour vous...")
#keyphrases = extract_keyphrases(extractor, textual_search, n=2)
print("Topics of interest:")
for keyphrase in keyphrases:
    similar_topics = find_similar_topics(keyphrase, all_topics_set)
    print(similar_topics)
# Out:
# --------------------------------------------------------------
# ----------------------- FILMOWLEDGE CLI ----------------------
# --------------------------------------------------------------
#
# Please describe what kind of movies you are looking for today:
# beast
#
# --------------------------------------------------------------
# Voici quelques suggestions de films pour vous...
# Topics of interest:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#      10 #keyphrases = extract_keyphrases(extractor, textual_search, n=2)
#      11 print("Topics of interest:")
# ---> 12 for keyphrase in keyphrases:
#      13     similar_topics = find_similar_topics(keyphrase, all_topics_set)
#      14     print(similar_topics)
#
# NameError: name 'keyphrases' is not defined

# %%
def categorize_input(input_string, n_groups):
    input_string = re.sub(r'[^a-zA-Z0-9 ]', '', input_string.replace('-', ' ').lower())
    print(input_string)
    words = input_string.split(' ')
    clusters = []
    for i in range(n_groups):
        clusters.append([])
        k = 0
        while k+i < len(words):
            clusters[i].append(' '.join(words[k:min(k+i+1, len(words))]))
            k = k+1
    return clusters
    
print(categorize_input("hello today the sky is blue. And i am in an endless-love!", 4))
# Out:
# hello today the sky is blue and i am in an endless love
# [['hello', 'today', 'the', 'sky', 'is', 'blue', 'and', 'i', 'am', 'in', 'an', 'endless', 'love'], ['hello today', 'today the', 'the sky', 'sky is', 'is blue', 'blue and', 'and i', 'i am', 'am in', 'in an', 'an endless', 'endless love'], ['hello today the', 'today the sky', 'the sky is', 'sky is blue', 'is blue and', 'blue and i', 'and i am', 'i am in', 'am in an', 'in an endless', 'an endless love'], ['hello today the sky', 'today the sky is', 'the sky is blue', 'sky is blue and', 'is blue and i', 'blue and i am', 'and i am in', 'i am in an', 'am in an endless', 'in an endless love']]

# %%
g = Graph()

# On charge les schémas
g.parse("../ontology/schema/MergedSchemas.ttl", format="turtle")
g.parse("topics.ttl", format="turtle")
g.parse("../Filmowledge/DataLifting/output.ttl", format="turtle")
# Out:
# <Graph identifier=Nd2a67351a92f4bf589fb0a8a0a313678 (<class 'rdflib.graph.Graph'>)>

# %%
def sparql_request_valid_topics(graph, topics):
    res = {i:[] for i in range(len(topics))}
    query = '''
        SELECT ?resource ?score
        WHERE {
        '''
    unions = []
    for i in range(len(topics)):
        topics_str = '"'+'"@en, "'.join(topics[i])+'"@en'
        unions.append(
        '''
          {
            # ?resource skos:prefLabel ?label 
            VALUES ?score {'''+ str(i+1) +'''}
            FILTER (?label IN ('''+ topics_str +'''))
          }
          ''')
    query = query + ' UNION '.join(unions) + '}'
    t_ = graph.query(query)
    for _ in t_:
        res[i].append(_.resource)
    return res
        

def sparql_request_from_topics(graph, topics):
    '''
    Requests the graph to retrieve the movies from the given topics.
    Topics has to be a list : names = ["Action", "Romantic", "Thriller", ...]
    '''
    topics = [':'+topic for topic in topics] # Add ':' to match the format of topics in the graph
    sparql_query = """
    PREFIX movie: <http://example.com/movie#>
    SELECT *
    WHERE {
        # ?movie movie:hasTopic ?topic.
        # ?movie movie:Title ?title.
        # ?movie movie:Popularity ?popularity.
        FILTER (?topic IN ( """ + ' '.join(topics) + """))
    }
    ORDER BY DESC(?popularity)
    """
    qres = g.query(sparql_query)
    for row in qres:
        print(f"{row.title} is about {row.topic} and has a popularity of {row.popularity}")
        
#Appel d'exemple, pour récupérer les films parlant de Criminals
#sparql_request_from_topics(g, ["Beast"])

r = sparql_request_valid_topics(g, categorize_input("hello today the sky is blue. And i am in an endless-love!", 4))
r
#sparql_request_from_topics(g, concat_res)
# Out:
# hello today the sky is blue and i am in an endless love
# {0: [],
#  1: [],
#  2: [],
#  3: [rdflib.term.URIRef('http://myvocab.org/Love'),
#   rdflib.term.URIRef('http://myvocab.org/Today'),
#   rdflib.term.URIRef('http://myvocab.org/Sky'),
#   rdflib.term.URIRef('http://myvocab.org/Blue'),
#   rdflib.term.URIRef('http://myvocab.org/EndlessLove')]}

# %%
sparql_request_from_topics(g, ["Beast"])
